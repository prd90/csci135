# %% [markdown]
# # Program 2-1: The Fickle Arrow of Fate
#
# THIS IS NOT HOMEWORK, BUT A FOR CREDIT ASSIGNMENT.  THIS ASSIGNMENT MUST BE COMPLETED INDIVIDUALLY.
#
# This program prints characters to form the shape of a downward pointing arrow composed of a rectangle shape and a right triangle shape (see example below).
#
# The arrow dimensions are defined by values for base height (bh), base width (bw), and head width (hw).  You should prompt the user to input these values.  The base width (bw) defines the number of characters on a line for the base part of the arrow.  The base height (bh) is the number of lines to print for the arraow base.  The head width (hw) specifies the number of characters to print on the first line of the arrow head.  Each subsequent line will have one less characters.  Some examples of the variable values are:
#
# A base height of 4, base width of 2, and head with of 6 would print
# >\*\*<br/>
# >\*\*<br/>
# >\*\*<br/>
# >\*\*<br/>
# >\*\*\*\*\*\*<br/>
# >\*\*\*\*\*<br/>
# >\*\*\*\*<br/>
# >\*\*\*<br/>
# >\*\*<br/>
# >\*
#
#
# A base height of 2, base width of 4, and head with of 5 would print
# >\*\*\*\*<br/>
# >\*\*\*\*<br/>
# >\*\*\*\*\*<br/>
# >\*\*\*\*<br/>
# >\*\*\*<br/>
# >\*\*<br/>
# >\*
#
# A simple version of the program has been provided for you in the code cell.  This program just prints an arrow of fixed size.  Make changes in the program to support the following requirements:
#
# 1. Prompt the user and read the values for base height, base height, and head width.
#
# 2. Use a loop to output an arrow base of the user entered base height and base width.
#
# 3. Create a second loop to output an arrow head of width **hw**.
#
# 4. Change the program to check the input values and only accept an head width that is *larger* than the base width. Use an input loop to continue prompting the user for a head width value until the value is larger than the base width.
#
# A sample input/output from a running program is (user inputs are in ***bold italic***):
#
# >Enter base height: ***5***<br/>
# >Enter base width: ***2***<br/>
# >Enter head width: ***4***<br/>
# >\*\*
# >\*\*
# >\*\*
# >\*\*
# >\*\*
# >\*\*\*\*
# >\*\*\*
# >\*\*
# >\*

# %%
##
## This is the base code.  You can run this to see what a sample output looks like, but you will need to make the changes
##   as specified in the requirements.
##

print('Welcome to your virtual arraow program!')

print('')
# Draw base (h = 3, bw = 2)
print ('**')
print ('**')
print ('**')

# Draw head (hw = 4)
print ('****')
print ('***')
print ('**')
print ('*')
