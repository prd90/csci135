# %% [markdown]
# # Program 2-2: Data are a Thing
#
# THIS IS NOT HOMEWORK, BUT A FOR CREDIT ASSIGNMENT.  THIS ASSIGNMENT MUST BE COMPLETED INDIVIDUALLY.
#
# Python is commonly used to analyze data. This is an example of doing just that. The U.S. Social Security Administration publishes lists of baby names for every year since 1880. This is a large amount of data is publicly available in a series of files. For this assignment, a portion of the data has been merged into a single smaller file. The data is stored in a *CSV (comma separated values)* file as discussed in the lecture and the lab.  The file is a list of baby names, with each line of the format:
#
# Year,Name,Gender(M/F),Number
#
# The *Number* is the number of children given the *Name* in that *Year*. Each line in the file is in the proper format (so you don't need to check for errors/missing data) and all duplicates have been removed (so you don't have to worry about that either). Please note that although there is no duplicate names in the same year for the same gender, the same name can be used twice (once for female and once for male).
#
# You are to create a program, with comments to document what you are doing, to provide information from this file:
#
# For this assignment, we will be using the data from the years 1990-2010 only.  You can disregard any other data.
#
# The file name is name_data.csv and is provided for you (you only need to open it and read/use the data).
#
# 1. Ask the user for a menu option for a function, the options are:
#
# >1 - Total names for a given year - where you will print out the total count of the all the names in the file for the chosen year  (see example below)<br/>
# >2 - Print all names for a given year, along with the number of times they were used that year - where you will print out, one per line (see example below), a list of names and the number of times they were used (this is the Name and Number fields in the file)<br/>
# >3 - How many name entries for that year in the file - where you will print out the count of the number of entries in the file for the chosen year  (see example below)<br />
# >q - Quit<br/>
#
# The code provided provides the menu of options for your convenience.
#
# 2. The program will ask for an option for the the function wanted, but you need to check the menu choice entered by the user fto make sure it is valud and handle errors without the program crashing.  When you get an invalid input for a menu choice, just keep asking for a menu option until you get a valid answer. There is no need to to reprint the menu after a user input error, just ask for a choice again.
#
# 3.  You will ask the user for a single year from 1990-2010.  You need to check for invalid entries and keep asking until you get a valid one.
#
# 4.  Print the answer, follwed by the menu options again until the user enters 'q'
#
# Sample Output Session (The Output Names and Numbers Are Examples Only. Actual numbers and names may vary).  THE USER INPUTS ARE IN ***bold italic***.
#
# >NAME DATA ANALYSIS<br/>
# ><br/>
# >1 - Total names for year<br/>
# >2 - All names/counts for year<br/>
# >3 - How many different names for year<br/>
# >q - Quit<br/>
# ><br/>
# >Menu Choice: ***1***<br/>
# >Year: ***1993***<br/>
# >1993 has 2739923 names<br/>
# ><br/>
# >NAME DATA ANALYSIS<br/>
# ><br/>
# >1 - Total names for year<br/>
# >2 - All names/counts for year<br/>
# >3 - How many different names for year<br/>
# >q - Quit<br/>
# ><br/>
# >Menu Choice: ***2***<br/>
# >Year: ***1995***<br/>
# >1995: Aaliyah: 1255<br/>
# >1995: Aaron: 13288<br/>
# >1995: Abby: 1378<br/>
# >1995: Abigail: 7821<br/>
# >1995: Abraham: 1287<br/>
# >1995: Adam: 10483<br/>
# >1995: Adrian: 3910<br/>
# >1995: Adriana: 2066<br/>
# >(A lot more entries will also be printed, but they are not shown here, just the starting and ending values)<br/>
# >1995: Wyatt: 2824<br/>
# >1995: Xavier: 2394<br/>
# >1995: Yesenia: 1495<br/>
# >1995: Zachary: 23129<br/>
# >1995: Zachery: 1533<br/>
# >1995: Zackary: 1192<br/>
# >1995: Zoe: 1726<br/>
# ><br/>
# >NAME DATA ANALYSIS<br/>
# ><br/>
# >1 - Total names for year<br/>
# >2 - All names/counts for year<br/>
# >3 - How many different names for year<br/>
# >q - Quit<br/>
# ><br/>
# >Menu Choice: ***r***<br/>
# >Invalid choice...Try again!<br/>
# >Menu Choice: ***3***<br/>
# >Year: ***1976***<br/>
# >Year must be from 1990 to 2010!<br/>
# >Starting Year: ***2003***<br/>
# >2003 had 609 different names<br/>
# >NAME DATA ANALYSIS<br/>
# ><br/>
# >1 - Total names for year<br/>
# >2 - All names/counts for year<br/>
# >3 - How many different names for year<br/>
# >q - Quit<br/>
# ><br/>
# >Menu Choice: ***q***<br>
#
# ### FINAL NOTES:
#
# It is easiest to get the solution by building the program incrementally. Work on one part and then add additional parts.
#
# Please note that the the programs will may be tested with other years than in the examples above to insure that they work properly. Partial credit will be given where applicable.
#
# HINT #1: You don't necessarily have to use the csv library referenced in the class (but you can if you want). Remember you can split a string with comma separated values. If you have a string called entry, you can say **entry.split(',')** and that will return a list of each entry (with no commas).
#
# HINT #2: If you use a dictionary in any part of your program (and there are many ways to do this without using dictionaries), there is a way you can get the *key* for the highest dictionary *value*. If your dictionary name is entry, the call **max(entry,key=entry.get)** will return the *key* associated with the maximum *value*.

# %%
##
## Program 2-2
##
##   This program imports the csv library.  You do not have to use that if you can process the data in some other way.
##

import csv

def menu():
    print('NAME DATA ANALYSIS\n')
    print('1 - Total names for year')
    print('2 - All names/counts for year')
    print('3 - How many different names for year')
    print('q - Quit\n')
